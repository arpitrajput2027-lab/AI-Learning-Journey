# %% [markdown]
# Methods for Data frame

# %%
import pandas as pd
# csv
df = pd.read_csv("05_employees_infos_2_.csv")

# df.head(3) # Gives 5(default) Starting Rows , customize3 via df.head(3)
# df.tail()  # Gives 5(default) Last Rows , customize3 via df.tail(3)
# df.sample() # Gives Random Rows , customize3 via df.sample(3)
# df.info()    # Give the Summary of the DATA
# df.shape   # Gives the(rows , columns )
# df.describe() # Gives Stastical info of the DATA
# df.columns  # Gives Column Head Info
df.nunique()  # Gives info about unique Count
# Out:
# ID            10
# Name          10
# Age           10
# Department     4
# Salary        10
# dtype: int64

# %%
print(df)
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000
