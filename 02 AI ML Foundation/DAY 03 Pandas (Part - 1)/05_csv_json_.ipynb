# %% [markdown]
# Pandas with csv and json files - Data give files

# %%
import pandas as pd
# csv
df = pd.read_csv("05_employees_infos_2_.csv")
print(df)
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
# json
df = pd.read_json("07_data.json")
print(df)
# Out:
#        name rating                   feedback   age
# 0     Alice     5             Great product!!  25.0
# 1       Bob   four       ok but late Delivery  30.0
# 2   Charlie    two            BAD EXPERIENCE    NaN
# 3     Diana      5                  Loved it!  28.0
# 4       Eve    3.5  Average - could be better  20.0
# 5     Alice      5       Great product again!  25.0
